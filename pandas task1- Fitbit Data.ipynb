# %% [markdown]
# #Task 1 - Fitbit Dataset
# <font color='red'>**1.Read this dataset in pandas , mysql and mongodb**</font>

# %% [markdown]
# <font color='blue' size="3">**Pandas**</font>

# %%
import pandas as pd

# %%
df = pd.read_csv("D:\ineuron\DataSets\FitBitdata.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2004-08-16       23014      20.389999        20.389999
# 453  8877689391   2004-09-16       16470       8.070000         8.070000
# 454  8877689391   2004-10-16       28497      27.530001        27.530001
# 455  8877689391   2004-11-16       10622       8.060000         8.060000
# 456  8877689391   2004-12-16        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# ___

# %% [markdown]
# <font color='blue' size="3">**MY SQL - automation**</font>

# %%
# !csvlook D:\ineuron\DataSets\FitBitdata.csv
# Out:
# |            Id | ActivityDate | TotalSteps | TotalDistance | TrackerDistance | LoggedActivitiesDistance | VeryActiveDistance | ModeratelyActiveDistance | LightActiveDistance | SedentaryActiveDistance | VeryActiveMinutes | FairlyActiveMinutes | LightlyActiveMinutes | SedentaryMinutes | Calories |
# | ------------- | ------------ | ---------- | ------------- | --------------- | ------------------------ | ------------------ | ------------------------ | ------------------- | ----------------------- | ----------------- | ------------------- | -------------------- | ---------------- | -------- |
# | 1,503,960,366 |   2016-03-25 |     11,004 |        7.110… |          7.110… |                   0.000… |             2.570… |                   0.460… |              4.070… |                  0.000… |                33 |                  12 |                  205 |              804 |    1,819 |
# ...

# %% [markdown]
# <font color='blue' size="3">**MY SQL - manual approach**</font>

# %%
import mysql.connector as conn
from mysql.connector import Error
try:
    mydb = conn.connect(host='localhost', user='root', passwd='Ineuron$93',database = 'datafit')
    if mydb.is_connected():
        cursor = mydb.cursor()
        #cursor.execute("CREATE DATABASE DataFit")
        #print("Database is created")
        #cursor.execute("select database datafit")
        #record = cursor.fetchone()
        #print("You're connected to database: ", record)
        #cursor.execute('DROP TABLE IF EXISTS fitbitdata;')
        print('Creating table....')

        cursor.execute("CREATE TABLE fitbitdata(Id bigint,ActivityDate date,TotalSteps int,TotalDistance float,TrackerDistance float,LoggedActivitiesDistance int,VeryActiveDistance float,ModeratelyActiveDistance float,LightActiveDistance float,SedentaryActiveDistance float,VeryActiveMinutes int,FairlyActiveMinutes int,LightlyActiveMinutes int,SedentaryMinutes int,Calories int)")
        print("Table is created....")
      
        for i,row in df.iterrows():
         
            query = "INSERT INTO datafit.fitbitdata VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(query, tuple(row))
            print("Record inserted")
            
        cursor.execute("CREATE TABLE Superstore(RowID int,OrderPriority varchar(20),Discount float,UnitPrice float,ShippingCost float,CustomerID int,CustomerName varchar(50),ShipMode varchar(15),CustomerSegment varchar(20),ProductCategory varchar(255),ProductSubCategory varchar(255),ProductContainer varchar(255),ProductName varchar(255),ProductBaseMargin float,Region varchar(20),StateorProvince varchar(20),City varchar(20),PostalCode int,OrderDate date,ShipDate date,Profit float,Quantityorderednew int,Sales float,OrderID int)")
        print("Table-2 is created....")
        
        for i,row in df1.fillna(-1).iterrows():
         
            query = "INSERT INTO datafit.Superstore VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(query, tuple(row))
            print("Record is inserted")
            
        mydb.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# Creating table....
# Error while connecting to MySQL 1050 (42S01): Table 'fitbitdata' already exists

# %% [markdown]
# ![mysql.png](attachment:mysql.png)

# %% [markdown]
# ---

# %% [markdown]
# <font color='blue' size="3">**Mongodb**</font>

# %%
import pymongo
import pandas as pd
import json

client = pymongo.MongoClient("mongodb+srv://Manasa_SM:Bhargav$93@manasa.atdo0.mongodb.net/?retryWrites=true&w=majority")
db = client.test

database = client['datafit']

collection = database["Superstore"]
collection1 = database["fitbitdata"]


dafr = pd.read_excel("D:\ineuron\DataSets\Superstore_USA.xlsx")
dafr.to_json('testjs.json')

with open('testjs.json') as file:
    file_data = json.load(file)
collection.insert_many([file_data])

dafr1 = pd.read_csv("D:\ineuron\DataSets\FitBit data.csv")
dafr1.to_json('test1js.json')

with open('test1js.json') as file:
    file_data1 = json.load(file)
collection1.insert_many([file_data1])

# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![mongo.png](attachment:mongo.png)

# %% [markdown]
# ![supermongo.png](attachment:supermongo.png)

# %% [markdown]
# ---

# %% [markdown]
# ___

# %% [markdown]
# <font color='red'>**3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format**</font>

# %%
pd.to_datetime(df.ActivityDate)
# Out:
# 0     2016-03-25
# 1     2016-03-26
# 2     2016-03-27
# 3     2016-03-28
# 4     2016-03-29
#          ...
# 452   2004-08-16
# 453   2004-09-16
# 454   2004-10-16
# 455   2004-11-16
# 456   2004-12-16
# Name: ActivityDate, Length: 457, dtype: datetime64[ns]

# %% [markdown]
# ![sql.png](attachment:sql.png)

# %%
df['ActivityDate']
# Out:
# 0      2016-03-25
# 1      2016-03-26
# 2      2016-03-27
# 3      2016-03-28
# 4      2016-03-29
#           ...
# 452    2004-08-16
# 453    2004-09-16
# 454    2004-10-16
# 455    2004-11-16
# 456    2004-12-16
# Name: ActivityDate, Length: 457, dtype: object

# %% [markdown]
# <font color='red'>**4 . Find out in this data that how many unique id's we have**</font>

# %% [markdown]
# ![mysql2.png](attachment:mysql2.png)

# %% [markdown]
# <font color='red'>**5 . which id is one of the active id that you have in whole dataset**</font>

# %%
 df.loc[df['VeryActiveMinutes'].idxmax()][['Id','VeryActiveMinutes']]
# Out:
# Id                   5577150313
# VeryActiveMinutes           202
# Name: 304, dtype: object

# %% [markdown]
# Hence Id - 5577150313 is the most active in the dataset

# %% [markdown]
# <font color='red'>**6 . how many of them have not logged there activity find out in terms of number of ids**</font>

# %%
df[df['LoggedActivitiesDistance'] == 0][['Id','LoggedActivitiesDistance']]
# Out:
#              Id  LoggedActivitiesDistance
# 0    1503960366                       0.0
# 1    1503960366                       0.0
# 2    1503960366                       0.0
# 3    1503960366                       0.0
# 4    1503960366                       0.0
# ..          ...                       ...
# 452  8877689391                       0.0
# 453  8877689391                       0.0
# 454  8877689391                       0.0
# 455  8877689391                       0.0
# 456  8877689391                       0.0
#
# [433 rows x 2 columns]

# %%
df.groupby(['Id'])['LoggedActivitiesDistance'].count()
# Out:
# Id
# 1503960366    19
# 1624580081    19
# 1644430081    10
# 1844505072    12
# 1927972279    12
# 2022484408    12
# 2026352035    12
# 2320127002    12
# 2347167796    15
# 2873212765    12
# 2891001357     8
# 3372868164    10
# 3977333714    12
# 4020332650    32
# 4057192912    32
# 4319703577    12
# 4388161847     8
# 4445114986    15
# 4558609924    12
# 4702921684    15
# 5553957443    12
# 5577150313    11
# 6117666160    10
# 6290855005    10
# 6391747486     9
# 6775888955     9
# 6962181067    14
# 7007744171    12
# 7086361926    12
# 8053475328    11
# 8253242879    12
# 8378563200    12
# 8583815059     8
# 8792009665    12
# 8877689391    12
# Name: LoggedActivitiesDistance, dtype: int64

# %% [markdown]
# <font color='red'>**7 . Find out who is the laziest person id that we have in dataset**</font>

# %%
df.groupby('Id')[['TotalDistance']].min().sort_values(by="TotalDistance")
# Out:
#             TotalDistance
# Id
# 2873212765           0.00
# 4388161847           0.00
# 4319703577           0.00
# 4057192912           0.00
# 6117666160           0.00
# 6290855005           0.00
# 2891001357           0.00
# 2347167796           0.00
# 4702921684           0.00
# 6391747486           0.00
# 6775888955           0.00
# 1844505072           0.00
# 8253242879           0.00
# 2320127002           0.00
# 8792009665           0.01
# 4020332650           0.01
# 1927972279           0.02
# 7086361926           0.02
# 1503960366           0.14
# 4445114986           0.19
# 8053475328           0.21
# 1624580081           0.53
# 3977333714           0.57
# 2026352035           0.63
# 4558609924           0.83
# 1644430081           0.97
# 5553957443           0.99
# 8583815059           1.10
# 8378563200           1.78
# 8877689391           1.78
# 5577150313           2.14
# 3372868164           3.04
# 2022484408           3.84
# 6962181067           3.90
# ...

# %%
df[['Id'],['TotalDistance']].groupby(['Id'])['TotalDistance'].size().nlargest(5).reset_index(name='top5')

# %%
df.groupby(['Id'])[['LightActiveDistance','LightlyActiveMinutes']].max().sort_values(by=["LightActiveDistance","LightlyActiveMinutes"])
# Out:
#             LightActiveDistance  LightlyActiveMinutes
# Id
# 4388161847                 0.00                     0
# 8253242879                 2.51                   150
# 2891001357                 3.22                   720
# 7086361926                 3.46                   204
# 8053475328                 3.88                   213
# 1927972279                 3.92                   267
# 3372868164                 4.05                   346
# 2026352035                 4.14                   263
# 8583815059                 4.24                   212
# 1844505072                 4.33                   305
# 5577150313                 4.44                   240
# 4445114986                 4.45                   316
# 6775888955                 4.68                   300
# 8792009665                 4.76                   328
# 4057192912                 4.97                   193
# 6290855005                 5.01                   280
# ...

# %% [markdown]
# <font color='red'>**8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset**</font>

# %%
df2 = df.query('Calories < 2500')[['Id','Calories']]

# %%
df2['Calories'].count()
# Out:
# 324

# %% [markdown]
# **Hence we have 324 healthy person in our dataset**

# %%
df.groupby(['Id'])['Calories'].max().sort_values()
# Out:
# Id
# 1624580081    1574
# 2026352035    1583
# 3977333714    1783
# 4388161847    1878
# 1844505072    1971
# 3372868164    2069
# 1503960366    2154
# 8253242879    2162
# 2320127002    2206
# 4558609924    2235
# 5553957443    2249
# 2873212765    2257
# 4319703577    2341
# 4445114986    2424
# 6962181067    2437
# 6391747486    2442
# 4057192912    2484
# 2347167796    2488
# 1927972279    2783
# 8583815059    2786
# 7086361926    2862
# 6117666160    2884
# 8792009665    3004
# 2022484408    3021
# 7007744171    3086
# 6290855005    3119
# 4702921684    3597
# 8053475328    3697
# 1644430081    4029
# 4020332650    4034
# 8378563200    4234
# 6775888955    4286
# 5577150313    4430
# 8877689391    4526
# 2891001357    4562
# Name: Calories, dtype: int64

# %% [markdown]
# <font color='red'>**9. how many person are not a regular person with respect to activity try to find out those**</font>

# %%
df.groupby(['ActivityDate','Id'])['Id'].count().duplicated().value_counts()
# Out:
# True     456
# False      1
# Name: Id, dtype: int64

# %% [markdown]
# Hence 1 person is not regular person with respect to ativity

# %%
df.groupby(['ActivityDate','TotalSteps','Id'])[['Id','TotalSteps']].sum()
# Out:
#                                             Id  TotalSteps
# ActivityDate TotalSteps Id
# 2003-12-16   0          4057192912  4057192912           0
#              5543       4020332650  4020332650        5543
# 2004-01-16   0          2320127002  2320127002           0
#                         2891001357  2891001357           0
#                         4057192912  4057192912           0
# ...                                        ...         ...
# 2016-03-31   6963       4702921684  4702921684        6963
#              7428       4020332650  4020332650        7428
#              8144       4319703577  4319703577        8144
#              12256      1503960366  1503960366       12256
#              14097      6962181067  6962181067       14097
#
# [457 rows x 2 columns]

# %% [markdown]
# <font color='red'>**10 . who is the thired most active person in this dataset find out those in pandas and in sql both**</font>

# %% [markdown]
# <font color='blue' size="3">**In Pandas**</font>

# %%
sorted(set(df['TotalSteps']))[-3]
# Out:
# 25701

# %% [markdown]
# <font color='blue' size="3">**In Mysql**</font>

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# <font color='red'>**11 . who is the 5th most laziest person avilable in dataset find it out**</font>

# %%
df3 = df.groupby(['TotalSteps','Id']).sum()

# %%
df3.loc[0:4]
# Out:
#                        TotalDistance  TrackerDistance  \
# TotalSteps Id
# 0          1844505072            0.0              0.0
#            2320127002            0.0              0.0
#            2347167796            0.0              0.0
#            2873212765            0.0              0.0
#            2891001357            0.0              0.0
#            4057192912            0.0              0.0
#            4319703577            0.0              0.0
#            4388161847            0.0              0.0
#            4702921684            0.0              0.0
#            6117666160            0.0              0.0
#            6290855005            0.0              0.0
#            6391747486            0.0              0.0
#            6775888955            0.0              0.0
#            8253242879            0.0              0.0
# 4          4057192912            0.0              0.0
#
#                        LoggedActivitiesDistance  VeryActiveDistance  \
# ...

# %% [markdown]
# Hence 2891001357 is the 5th laziest person in the dataset

# %% [markdown]
# <font color='red'>**12 . what is a totla acumulative calories burn for a person find out**</font>

# %%
def weightcal(a):
    b = a * 150
    return b

for r in df.Calories:
    weightcal(r)


df['calorie_burnt'] = df['TrackerDistance'].apply(weightcal)

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...
